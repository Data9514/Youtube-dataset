# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\dinak\AppData\Local\Temp\ipykernel_19644\3090805088.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# 1. 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records. (3 marks)
df=pd.read_csv('youtube_dislike_dataset.csv')
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
top5_list = df[:5]
top5_list
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
bottom5_list = df [37417:]
bottom5_list
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %%
# 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.
print(df.dtypes)
print(df.shape)
df.info()
# Out:
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# published_at     object
# view_count        int64
# likes             int64
# dislikes          int64
# comment_count     int64
# tags             object
# description      object
# comments         object
# dtype: object
# (37422, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
# ...

# %%
#3.Check for the Percentage of the missing values and drop or impute them.
from sklearn.impute import SimpleImputer


missing_percentage = df.isnull().mean() * 100
print("Missing Percentage:")
print(missing_percentage[missing_percentage > 0])
threshold = 50  
columns_to_drop = missing_percentage[missing_percentage > threshold].index
df = df.drop(columns=columns_to_drop)
imputer = SimpleImputer(strategy='mean')
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

print("After Handling Missing Values:")
# Out:
# Missing Percentage:
# comments    0.422212
# dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 12
#      10 df = df.drop(columns=columns_to_drop)
#      11 imputer = SimpleImputer(strategy='mean')
# ---> 12 df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)
#      14 print("After Handling Missing Values:")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:273, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     271 @wraps(f)
#     272 def wrapped(self, X, *args, **kwargs):
# --> 273     data_to_wrap = f(self, X, *args, **kwargs)
#     274     if isinstance(data_to_wrap, tuple):
#     275         # only wrap the first output for cross decomposition
#     276         return_tuple = (
# ...

# %%
df.isnull()
# Out:
#        video_id  title  channel_id  channel_title  published_at  view_count  \
# 0         False  False       False          False         False       False
# 1         False  False       False          False         False       False
# 2         False  False       False          False         False       False
# 3         False  False       False          False         False       False
# 4         False  False       False          False         False       False
# ...         ...    ...         ...            ...           ...         ...
# 37417     False  False       False          False         False       False
# 37418     False  False       False          False         False       False
# 37419     False  False       False          False         False       False
# 37420     False  False       False          False         False       False
# 37421     False  False       False          False         False       False
#
# ...

# %%
# 4.Check the statistical summary of both numerical and categorical columns and write your inferences.
df.describe()
df.describe(include ='O')
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description  \
# count                 37422  37422       37422
# unique                36772  28799       35630
# top     2020-10-16 04:00:10
# freq                      6   3817         589
#
#                                                  comments
# count                                               37264
# unique                                              37264
# top     Respect to Dortmund fans,must be sad losing hi...
# freq                                                    1

# %%
# 5. Convert datatype of column published_at from object to pandas datetime.
df['published_at'] = pd.to_datetime(df['published_at'])
df.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# dtype: object

# %%
# 6.Create a new column as 'published_month' using the column published_at (display the months only)
df['published_month'] = df['published_at'].dt.month
print(df[['published_at', 'published_month']])
# Out:
#              published_at  published_month
# 0     2021-07-01 10:00:00                7
# 1     2021-06-10 16:00:00                6
# 2     2021-09-20 01:03:32                9
# 3     2021-03-03 10:00:17                3
# 4     2021-12-07 13:00:00               12
# ...                   ...              ...
# 37417 2021-02-12 05:03:49                2
# 37418 2021-01-16 05:39:05                1
# 37419 2021-06-02 09:00:10                6
# 37420 2020-10-20 20:59:30               10
# 37421 2021-05-23 21:00:31                5
#
# [37422 rows x 2 columns]

# %%
# 7.Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on..... 
df['published_month'] = df['published_at'].dt.month.map({1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'})
print(df[['published_at', 'published_month']])
# Out:
#              published_at published_month
# 0     2021-07-01 10:00:00             Jul
# 1     2021-06-10 16:00:00             Jun
# 2     2021-09-20 01:03:32             Sep
# 3     2021-03-03 10:00:17             Mar
# 4     2021-12-07 13:00:00             Dec
# ...                   ...             ...
# 37417 2021-02-12 05:03:49             Feb
# 37418 2021-01-16 05:39:05             Jan
# 37419 2021-06-02 09:00:10             Jun
# 37420 2020-10-20 20:59:30             Oct
# 37421 2021-05-23 21:00:31             May
#
# [37422 rows x 2 columns]

# %%
# 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.
# Group by 'published_month' and count the number of videos
monthly_video_count = df['published_month'].value_counts().reset_index()
monthly_video_count.columns = ['Month', 'Video Count']

# Arrange months in decreasing order based on video count
monthly_video_count = monthly_video_count.sort_values(by='Video Count', ascending=False)


print(monthly_video_count)
# Out:
#    Month  Video Count
# 0    Oct         4991
# 1    Sep         4880
# 2    Nov         4851
# 3    Aug         4262
# 4    Dec         3072
# 5    Jul         2340
# 6    Jun         2316
# 7    Mar         2258
# 8    Feb         2137
# 9    Apr         2126
# 10   Jan         2108
# 11   May         2081

# %%
# 9. Find the count of unique video_id, channel_id and channel_title.
unique_video_id_count = df['video_id'].nunique()
unique_channel_id_count = df['channel_id'].nunique()
unique_channel_title_count = df['channel_title'].nunique()

# results
print("Unique Video ID Count:", unique_video_id_count)
print("Unique Channel ID Count:", unique_channel_id_count)
print("Unique Channel Title Count:", unique_channel_title_count)
# Out:
# Unique Video ID Count: 37422
# Unique Channel ID Count: 10961
# Unique Channel Title Count: 10883

# %%
# 10.Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

channel_video_counts = df['channel_title'].value_counts()

# Top 10 channels with the highest number of videos
top_10_channels = channel_video_counts.head(10)

# Bottom 10 channels with the lowest number of videos
bottom_10_channels = channel_video_counts.tail(10)

#  results
print("Top 10 Channels (Highest Number of Videos):")
print(top_10_channels)

print("\nBottom 10 Channels (Lowest Number of Videos):")
print(bottom_10_channels)
# Out:
# Top 10 Channels (Highest Number of Videos):
# channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: count, dtype: int64
#
# Bottom 10 Channels (Lowest Number of Videos):
# channel_title
# Eiaz                     1
# adidas                   1
# Universitetet i Agder    1
# Team Tapia               1
# TheVincentMottola        1
# Blocktrainer             1
# Movie Addicts            1
# 1 1 minute mom           1
# FLORIN CERCEL            1
# Master Podcast           1
# Name: count, dtype: int64

# %%
# 11.Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

max_likes_video_title = df.loc[df['likes'].idxmax()]['title']

# Find the title of the video with the minimum number of likes
min_likes_video_title = df.loc[df['likes'].idxmin()]['title']

#  results
print("Video with the Maximum Likes:")
print("Title:", max_likes_video_title)
print("Number of Likes:", df['likes'].max())

print("\nVideo with the Minimum Likes:")
print("Title:", min_likes_video_title)
print("Number of Likes:", df['likes'].min())
# Out:
# Video with the Maximum Likes:
# Title: BTS () 'Dynamite' Official MV
# Number of Likes: 31837675
#
# Video with the Minimum Likes:
# Title: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News
# Number of Likes: 0

# %%
# 12.Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

max_dislikes_video_title = df.loc[df['dislikes'].idxmax()]['title']

# Find the title of the video with the minimum number of dislikes
min_dislikes_video_title = df.loc[df['dislikes'].idxmin()]['title']

# Display the results
print("Video with the Maximum Dislikes:")
print("Title:", max_dislikes_video_title)
print("Number of Dislikes:", df['dislikes'].max())

print("\nVideo with the Minimum Dislikes:")
print("Title:", min_dislikes_video_title)
print("Number of Dislikes:", df['dislikes'].min())
# Out:
# Video with the Maximum Dislikes:
# Title: Cuties | Official Trailer | Netflix
# Number of Dislikes: 2397733
#
# Video with the Minimum Dislikes:
# Title: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News
# Number of Dislikes: 0

# %%
# 13.Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

df['view_count'] = pd.to_numeric(df['view_count'], errors='coerce')
df['dislikes'] = pd.to_numeric(df['dislikes'], errors='coerce')
correlation_coefficient = df['view_count'].corr(df['dislikes'])
plt.figure(figsize=(10, 6))
plt.scatter(df['view_count'], df['dislikes'], alpha=0.5)
plt.title('Scatter Plot of Views vs Dislikes')
plt.xlabel('Number of Views')
plt.ylabel('Number of Dislikes')
plt.show()
print(f"Correlation Coefficient between Views and Dislikes: {correlation_coefficient}")
# Out:
# Correlation Coefficient between Views and Dislikes: 0.6844687753905547

# %%
# 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

df['published_at'] = pd.to_datetime(df['published_at'])

# Create a new column 'published_month' with the names of the months
df['published_month'] = df['published_at'].dt.month.map({1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'})

# Filter the DataFrame for videos published in January
january_videos = df[df['published_month'] == 'Jan']

# Display information about videos published in January
print("Information about Videos Published in January:")
print(january_videos)

# Mention the count of videos published in January
january_video_count = january_videos.shape[0]
print(f"\nCount of Videos Published in January: {january_video_count}")
# Out:
# Information about Videos Published in January:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
df.describe()
# Out:
#                         published_at    view_count         likes  \
# count                          37422  3.742200e+04  3.742200e+04
# mean   2021-04-10 13:04:18.237827840  5.697838e+06  1.668147e+05
# min              2020-07-27 21:49:32  2.036800e+04  0.000000e+00
# 25%    2020-12-01 12:00:13.750000128  5.122970e+05  1.323350e+04
# 50%              2021-04-10 11:00:11  1.319078e+06  4.233050e+04
# 75%    2021-08-15 23:00:08.249999872  3.670231e+06  1.304698e+05
# max              2021-12-08 05:20:47  1.322797e+09  3.183768e+07
# std                              NaN  2.426622e+07  5.375670e+05
#
#            dislikes  comment_count
# count  3.742200e+04   3.742200e+04
# mean   4.989862e+03   9.924930e+03
# min    0.000000e+00   0.000000e+00
# 25%    2.810000e+02   9.000000e+02
# 50%    7.960000e+02   2.328000e+03
# 75%    2.461750e+03   6.184000e+03
# max    2.397733e+06   1.607103e+07
# std    3.070824e+04   1.171003e+05
